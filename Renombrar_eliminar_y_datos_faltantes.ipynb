# %% [markdown]
# <a href="https://colab.research.google.com/github/MegaPlayer64/CodingDojoDataScienceClasses/blob/First-Activities/Renombrar_eliminar_y_datos_faltantes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Renombrar, eliminar y datos faltantes:**

# %%
import pandas as pd
filename = '/content/RailsToTrails_National_Count_Data_week.xlsx'
df = pd.read_excel(filename)
df = df.rename(columns={'Unnamed: 6': 'percent_change',
                      ' 2019 counts (31 counters)': 'counts_2019',
                      ' 2020 counts (31 counters)': 'counts_2020',})
df = df.drop(columns=['Unnamed: 7'])
df = df.drop(columns=['Unnamed: 8'])
df = df.drop(columns=['Unnamed: 9'])
df['2021 Counts'].fillna(0, inplace=True)
df.head()
# Out:
#   Timeframe    Week of  counts_2019  counts_2020  2021 Counts  \
# 0    Week 1 2020-12-30       167679       183546          0.0
# 1    Week 2 2020-01-06        82340        97140          0.0
# 2    Week 3 2020-01-13        62315        75782          0.0
# 3    Week 4 2020-01-20        75801        83809          0.0
# 4    Week 5 2020-01-27        75841        94738          0.0
#
#    Change 2019-2020  percent_change
# 0          0.094627        1.094627
# 1          0.179743      117.974253
# 2          0.216112      121.611169
# 3          0.105645      110.564504
# 4          0.249166      124.916602
